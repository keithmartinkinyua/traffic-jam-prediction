# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Desktop/traffic-jam-competition/train_revised.csv")
data
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3         5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4         5778         11A          Mpesa      BM97HFRGL9    27-11-17
# 5         5777         18B          Mpesa      B6PBDU30IZ    27-11-17
# 6         5777         14A          Mpesa      MZHGDGS6QZ    27-11-17
# 7         5778          25          Mpesa      MYVTYFNXDZ    27-11-17
# 8         5778         21B          Mpesa      TE1WYK1NYE    27-11-17
# 9         5781         22A          Mpesa      VGG7Q3MVJX    27-11-17
# 10        5781         18B          Mpesa      YJ7JFHOGKA    27-11-17
# 11        5781         17B          Mpesa      4JQOSC881A    27-11-17
# ...

# %%
dataa = data.replace({"Bus" : "1", "shuttle" : "0"}, inplace = False)
dataa


#new_data = inputs_for_svm.replace({'female':'0', 'male':'1'}, inplace = False)
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3         5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4         5778         11A          Mpesa      BM97HFRGL9    27-11-17
# 5         5777         18B          Mpesa      B6PBDU30IZ    27-11-17
# 6         5777         14A          Mpesa      MZHGDGS6QZ    27-11-17
# 7         5778          25          Mpesa      MYVTYFNXDZ    27-11-17
# 8         5778         21B          Mpesa      TE1WYK1NYE    27-11-17
# 9         5781         22A          Mpesa      VGG7Q3MVJX    27-11-17
# 10        5781         18B          Mpesa      YJ7JFHOGKA    27-11-17
# 11        5781         17B          Mpesa      4JQOSC881A    27-11-17
# ...

# %%
scores = dataa.pivot_table(index = ['travel_from'], columns = ['travel_date'], values = 'max_capacity')
scores
# Out:
# travel_date   01-01-18   01-02-18   01-03-18   01-04-18   01-12-17  02-01-18  \
# travel_from
# Awendo             NaN        NaN        NaN  49.000000        NaN       NaN
# Homa Bay     49.000000  49.000000  49.000000        NaN        NaN      49.0
# Kehancha           NaN        NaN  49.000000  49.000000        NaN       NaN
# Kendu Bay          NaN        NaN        NaN        NaN        NaN       NaN
# Keroka       11.000000  49.000000  49.000000  49.000000  11.000000       NaN
# Keumbu             NaN        NaN        NaN  49.000000  11.000000       NaN
# Kijauri            NaN  21.857143  30.000000  19.866667        NaN       NaN
# Kisii        23.666667  19.068493  18.307692  20.500000  12.085714      30.0
# Mbita              NaN        NaN        NaN        NaN        NaN       NaN
# Migori       49.000000  49.000000  49.000000  49.000000  49.000000      49.0
# Ndhiwa             NaN        NaN        NaN        NaN        NaN       NaN
# ...

# %%
#performance = [10,8,6,4,2,1]
#plt.plot(scores)
#plt.figure(figsize=(10,10))
#plt.show(scores)

# %%
list_of_datetimes = dataa.travel_time.values
int(list_of_datetimes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7a064f5c4fea> in <module>()
#       1 list_of_datetimes = dataa.travel_time.values
# ----> 2 int(list_of_datetimes)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
#dataa["travel_time"]

# %%
#times = {'Dawn' : 03:00 - 07:00, 'Morning' : 07:00 - 11:00, 'Noon' : 11:00 - 13:00, 'Afternoon' : 13:00 - 16:00, 'Afternoon' : 13:00 - 16:00, 'Evening' : 16:00 - 19:00, 'Night' : 19:00 - 22:00, 'Midnight' : 22:00 - 00:00, 'Past-midnight' : 00:00 - 03:00}

# %%
dataa.travel_time.value_counts(normalize = True).plot(kind = 'kde', alpha = 0.5)
#plt.subplot2grid(2,3),(0,0)
fig = plt.figure(figsize = (38,16))

# %%
dataa.car_type[(dataa.travel_from == "Migori") & (dataa.travel_to == "Nairobi")].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.car_type[(dataa.travel_from == "Kisii") & (dataa.travel_to == "Nairobi")].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.car_type[(dataa.travel_from == "Ndhiwa") & (dataa.travel_to == "Nairobi")].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.car_type[(dataa.travel_from == "Kehancha") & (dataa.travel_to == "Nairobi")].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.car_type[(dataa.travel_from == "Awendo") & (dataa.travel_to == "Nairobi")].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.max_capacity[(dataa.travel_from == "Awendo") & (dataa.travel_to == "Nairobi")].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.max_capacity[(dataa.travel_from == "Kisii") & (dataa.travel_to == "Nairobi")].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.travel_to[(dataa.travel_from == "Kisii") & (dataa.travel_time == '7:15')].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
dataa.travel_to[(dataa.travel_from == "Keroka") & (dataa.travel_time)].value_counts(normalize = True).plot(kind = "bar", alpha = 0.5)

# %%
list_of_datetimes = dataa.travel_time.values

# %%
import datetime

dates = plt.dates.date2num(list_of_datetimes)
plt.plot_date(dates, values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-11b0bcdc2de4> in <module>()
#       1 import datetime
#       2
# ----> 3 dates = plt.dates.date2num(list_of_datetimes)
#       4 plt.plot_date(dates, values)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'dates'

# %%
import datetime

x = [datetime.datetime.now() + datetime.timedelta(hours=i) for i in range(12)]
y = list_of_datetimes

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-4c9dc376153e> in <module>()
#       5
#       6 # plot
# ----> 7 plt.plot(x,y)
#       8 # beautify the x-labels
#       9 plt.gcf().autofmt_xdate()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
#pt = dataa.pivot_table(index = "travel_date", columns = "max_capacity", values = "travel_time")

# %%
Product_Category_1from sklearn import linear_model

model = linear_model.LinearRegression()
model_ = model.fit(dataa, list_of_datetimes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2fa2cd532801> in <module>()
#       2
#       3 model = linear_model.LinearRegression()
# ----> 4 model_ = model.fit(dataa, list_of_datetimes)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
dataa.corr()
# Out:
#                ride_id  max_capacity
# ride_id       1.000000      0.295902
# max_capacity  0.295902      1.000000
